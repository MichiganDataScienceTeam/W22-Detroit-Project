# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("no_dup_data.csv")
# Out:
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.to_csv('mess.csv')

# %%
mess = pd.read_csv("mess.csv")
mess.dropna(subset = ["neighborhood", "council_district"], inplace=True)
# Out:
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mess.head()
# Out:
#         Unnamed: 0          X          Y       id status  \
# 132734      132734 -83.238052  42.431499  5932259   Open
# 132736      132736 -83.164932  42.383934  5932239   Open
# 132738      132738 -82.945694  42.418099  5932216   Open
# 132740      132740 -82.940814  42.420735  5932205   Open
# 132742      132742 -83.279101  42.413472  5932193   Open
#
#                               request_type_title  \
# 132734                        Illegal Dump Sites
# 132736         Rodent Extermination - BSEED Only
# 132738                                  Potholes
# 132740                        Illegal Dump Sites
# 132742  DPW - Other environmental - DPW USE ONLY
#
#                                               description  \
# 132734                  BAGS DUMPED ON CURB OF VACANT LOT
# 132736                                                NaN
# 132738  one large pothole located on Balfour btw Britt...
# 132740  BLDG MATERIALS - TREE DEBRIS - WOOD - MISC DEB...
# ...

# %%
mess = mess.sort_values(["council_district"], ascending = True)
print(len(mess))
# Out:
# 162811

# %%
mess.head()
# Out:
#         Unnamed: 0          X          Y       id    status  \
# 132734      132734 -83.238052  42.431499  5932259      Open
# 297221      297221 -83.207741  42.392922  2010000  Archived
# 195675      195675 -83.258232  42.436560  4170563  Archived
# 195676      195676 -83.256251  42.436702  4170559  Archived
# 195678      195678 -83.255692  42.436716  4170540  Archived
#
#                               request_type_title  \
# 132734                        Illegal Dump Sites
# 297221                    Street Light Pole Down
# 195675  DPW - Other environmental - DPW USE ONLY
# 195676  DPW - Other environmental - DPW USE ONLY
# 195678  DPW - Other environmental - DPW USE ONLY
#
#                                               description  \
# 132734                  BAGS DUMPED ON CURB OF VACANT LOT
# 297221  Pole hit on Mon @ 11:00 pm approx\n\nElectric ...
# 195675                             AREA SURVEY INSPECTION
# 195676                             AREA SURVEY INSPECTION
# ...

# %%
print(len(mess))
# Out:
# 162811

# %%
data.to_csv("coun1.csv")
coun1 = pd.read_csv("coun1.csv")
coun1 = coun1[coun1.council_district == 1.0]
data.to_csv("coun2.csv")
coun2 = pd.read_csv("coun2.csv")
coun2 = coun2[coun2.council_district == 2.0]
data.to_csv("coun3.csv")
coun3 = pd.read_csv("coun3.csv")
coun3 = coun3[coun3.council_district == 3.0]
data.to_csv("coun4.csv")
coun4 = pd.read_csv("coun4.csv")
coun4 = coun4[coun4.council_district == 4.0]
data.to_csv("coun5.csv")
coun5 = pd.read_csv("coun5.csv")
coun5 = coun5[coun5.council_district == 5.0]
data.to_csv("coun6.csv")
coun6 = pd.read_csv("coun6.csv")
coun6 = coun6[coun6.council_district == 6.0]
data.to_csv("coun7.csv")
coun7 = pd.read_csv("coun7.csv")
coun7 = coun7[coun7.council_district == 7.0]
# Out:
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ...

# %%
print(len(coun1))
print(len(coun2))
print(len(coun3))
print(len(coun4))
print(len(coun5))
print(len(coun6))
print(len(coun7))
# Out:
# 23762
# 20727
# 18947
# 22361
# 21134
# 21097
# 34963

# %%
coun1["request_type_title"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
coun2["request_type_title"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
coun3["request_type_title"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
coun4["request_type_title"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
coun5["request_type_title"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
coun6["request_type_title"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
coun7["request_type_title"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.to_csv("pri1.csv")
pri1 = pd.read_csv("pri1.csv")
pri1 = pri1[pri1.priority_code == 1]
data.to_csv("pri2.csv")
pri2 = pd.read_csv("pri2.csv")
pri2 = pri2[pri2.priority_code == 2]
data.to_csv("pri3.csv")
pri3 = pd.read_csv("pri3.csv")
pri3 = pri3[pri3.priority_code == 3]
# Out:
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/jessegilbert-sovern/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pri1["council_district"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
pri2["council_district"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
pri3["council_district"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>
